# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data set
from sklearn.datasets import load_boston
X=load_boston()
# Out:
# H:\ananconda1\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df=pd.DataFrame(X.data, columns=X.feature_names)
#X=df
#Y=df.iloc[:,-1]

df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
#load the data set
from sklearn.datasets import load_boston
X=load_boston()
df=pd.DataFrame(X.data, columns=X.feature_names)

    
#output/target column-predicted or dependent column
df["MEDV"]=X.target #target puts it at the end

#feature matrix-independent columns
X=df.drop("MEDV",1)
Y=df["MEDV"]
df
# Out:
# H:\ananconda1\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
plt.figure(figsize=(12,10))


#correlations
cor= df.corr()
cor
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#feature matrix
#obtain strongly correlated features>filter them
#feature matirx vs the target/output  variable>pick the feature that is strongly correlated to the target
cor_target= abs(cor['MEDV'])
cor_target
# Out:
# CRIM       0.388305
# ZN         0.360445
# INDUS      0.483725
# CHAS       0.175260
# NOX        0.427321
# RM         0.695360
# AGE        0.376955
# DIS        0.249929
# RAD        0.381626
# TAX        0.468536
# PTRATIO    0.507787
# B          0.333461
# LSTAT      0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
relevant_features=cor_target[cor_target>0.5]
relevant_features
# Out:
# RM         0.695360
# PTRATIO    0.507787
# LSTAT      0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
print(df[["LSTAT", "PTRATIO"]].corr())
print(df[['RM', "LSTAT"]].corr())
# Out:
#             LSTAT   PTRATIO
# LSTAT    1.000000  0.374044
# PTRATIO  0.374044  1.000000
#              RM     LSTAT
# RM     1.000000 -0.613808
# LSTAT -0.613808  1.000000

# %%
#from the above tab results, the first comparison is weakly correlated
#RM and Lstat provide the problem as they are highly correlated
#we pick Lstat and drop rm because it is highly correlated than rm when compared to the target

# %%
#wrapper method

##backward elimination
##foward selection
##Bidrectional Elimination
##recursive feature eliminaton(RFE)- its iterative


#ordinary least squares(OLS)
import statsmodels.api as sm

#add constant column of ones,
#mandatory for sm.OLS model-ordinary least squares

X_1=sm.add_constant(X)

model=sm.OLS(Y, X_1).fit()
#model.fit()
#0r model=sm.OLS(Y, X_1).fit

#p-value of 0.05 or 0.005

model.pvalues
# Out:
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const      3.283438e-12
# CRIM       1.086810e-03
# ZN         7.781097e-04
# INDUS      7.382881e-01
# CHAS       1.925030e-03
# NOX        4.245644e-06
# RM         1.979441e-18
# AGE        9.582293e-01
# DIS        6.013491e-13
# RAD        5.070529e-06
# TAX        1.111637e-03
# PTRATIO    1.308835e-12
# B          5.728592e-04
# LSTAT      7.776912e-23
# dtype: float64

# %%
#if p-value is above 0.05, we remove the feature 
#else we keep it

# %%
cols=list(X.columns)
X_1=X[cols]
    
X_1=sm.add_constant(X_1)
X_1
# Out:
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#      const     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0      1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1      1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2      1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3      1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4      1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..     ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501    1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502    1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503    1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# ...

# %%
# %%time
#cols=list(X.columns)

#for i in X:
    #X.apply(lambda x: "Present" if model.pvalues>0.05 else "not")
# Out:
# Wall time: 0 ns

# %%
# %%time
cols=list(X.columns)

pmax=1

while(len(cols)>1):
    p=[]
    
    X_1=X[cols]
    
    X_1=sm.add_constant(X_1)
    model=sm.OLS(Y, X_1).fit()
    p=pd.Series(model.pvalues.values[1:], index=cols)
    
    pmax=max(p)
    
    feature_with_p_max=p.idxmax()
    
    if(pmax> 0.05):
        cols.remove(feature_with_p_max)
    else:
        break
        
selected_features=cols
print(selected_features)
# Out:
# ['CRIM', 'ZN', 'CHAS', 'NOX', 'RM', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Wall time: 31.2 ms
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# %%time
def myfunc(colss):
    cols=list(colss)
    pmax=1
    while(len(colss)>1):
        p=[]
        X_new=X[cols]
        X_new=sm.add_constant(X_new)
        model=sm.OLS(Y, X_new).fit()
        p=pd.Series(model.pvalues.values[1:], index=cols)
        pmax=max(p)
        feature_with_p_max=p.idxmax()
        if(pmax> 0.05):
            cols.remove(feature_with_p_max)
        else:
            break
        selected_features=cols
        return selected_features
myfunc(X.columns)
# Out:
# Wall time: 5.11 ms
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %%
# %%time

def myfunc(colss):
    cols=list(colss.columns)
    pmax=1

    while(len(cols)>1):
        p=[]
    
        X_new=X[cols]
    
        X_new=sm.add_constant(X_new)
        model=sm.OLS(Y, X_new).fit()
        p=pd.Series(model.pvalues.values[1:], index=cols)
    
        pmax=max(p)
    
        feature_with_p_max=p.idxmax()
    
        if(pmax> 0.05):
            cols.remove(feature_with_p_max)
        else:
            break
        selected_features=cols  
        return selected_features

myfunc(X)
# Out:
# Wall time: 15.6 ms
# H:\ananconda1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %% [markdown]
# **Initilize x and y**

# %%
#determinants/independent columns

x=df[['CRIM','ZN','CHAS','NOX','RM','DIS','RAD','TAX','PTRATIO','B','LSTAT']]

#target/dependent column
y=df["MEDV"]

# %% [markdown]
# **Import RandomForestRegressor**

# %%
#import randomRegressor model
from  sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import train_test_split


#set random seed
np.random.seed(42)

#split data into trian and test
X_train, X_test, Y_train, Y_test=train_test_split(x,y, test_size=0.3)

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((354, 11), (152, 11), (354,), (152,))

# %%
model=RandomForestRegressor()
#model.get_params()

# %%
model=RandomForestRegressor(n_estimators=200)
model.fit(X_train, Y_train)

model.score(X_test,Y_test)
# Out:
# 0.872306318803672

# %%
predictions=model.predict(X_test)
predictions
# Out:
# array([23.1925, 31.2785, 16.4295, 23.908 , 17.3535, 21.547 , 19.898 ,
#        14.6365, 21.77  , 21.07  , 20.7325, 20.524 ,  7.9355, 21.3455,
#        19.6465, 25.47  , 19.3795,  8.172 , 45.065 , 15.847 , 24.0575,
#        24.1495, 15.018 , 23.897 , 15.3275, 16.7585, 21.1755, 13.8645,
#        20.958 , 21.4675, 19.7825, 23.162 , 29.932 , 20.297 , 15.491 ,
#        15.9255, 34.7145, 19.0255, 21.0515, 23.694 , 17.208 , 29.411 ,
#        44.8245, 19.7575, 22.821 , 14.172 , 16.94  , 24.0025, 18.4875,
#        27.183 , 21.64  , 33.64  , 17.8925, 26.47  , 45.577 , 21.5815,
#        16.116 , 32.1555, 22.438 , 20.244 , 25.48  , 33.44  , 30.6045,
#        18.645 , 26.8435, 19.169 , 13.354 , 23.1385, 27.865 , 15.654 ,
#        20.594 , 29.093 , 10.48  , 22.262 , 21.6435,  6.8545, 20.447 ,
#        46.0125, 11.1345, 13.332 , 21.7765, 11.7685, 19.626 ,  9.078 ,
#        21.236 , 27.0845, 15.852 , 23.261 , 23.6525, 17.725 , 21.9995,
# ...

# %% [markdown]
# **Evaluate the Model**

# %%
#using mean_absolute_error

from sklearn.metrics import mean_absolute_error


mae=mean_absolute_error(Y_test, predictions)
mae
# Out:
# 2.112348684210524

# %%
p=pd.DataFrame(data={"Actual YTest Values":Y_test, "Predictions": predictions})
p
# Out:
#      Actual YTest Values  Predictions
# 173                 23.6      23.1925
# 274                 32.4      31.2785
# 491                 13.6      16.4295
# 72                  22.8      23.9080
# 452                 16.1      17.3535
# ..                   ...          ...
# 441                 17.1      13.7095
# 23                  14.5      15.9930
# 225                 50.0      43.4825
# 433                 14.3      15.1710
# 447                 12.6      16.4115
#
# [152 rows x 2 columns]

# %%
#predict random values
#number of values should be same as number of columns
random=[[0.005,14,0.1,0.9,5.4,32,3.2,2,315,12.4,500]]

model.predict(random)
# Out:
# H:\ananconda1\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([15.9645])

# %% [markdown]
# **Saving the Model**

# %%
import pickle

with open("mod", "wb") as file:
    pickle.dump(model, file)

# %%
#from sklearn.metrics import r2_score


#mean_test=np.full(len(Y_test), predictions.mean())

#r2_score(Y_test,mean_test)
# Out:
# -5.142415393244448e-05
